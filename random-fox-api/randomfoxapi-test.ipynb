# %% [markdown]
# # Random Fox API

# %%
from randomfoxapi import randomfoxAPI

# %%
fox = randomfoxAPI()

# %%
help(fox)
# Out:
# Help on randomfoxAPI in module randomfoxapi object:
#
# class randomfoxAPI(builtins.object)
#  |  Class used to request a random image of an fox
#  |
#  |  Attributes
#  |  ----------
#  |  img : Image
#  |      Image requested
#  |  imgsize : tuple
#  |      the dimensions of the image
#  |
#  |  Methods
#  |  -------
#  |  req_image()
#  |      Request the image
#  |
#  |  resize_image(size)
#  |      Replaces the existing image with a new one with the dimensions indicated in 'size'
#  |
#  |  save_image(name, path)
#  |      Saves the existing
#  |
#  |  Methods defined here:
#  |
#  |  __init__(self)
#  |      Parameters:
#  |      ----------
#  |      No parameters
#  |
#  |      Description:
#  |      -----------
#  |      Inits the class
#  |
#  |  req_image(self)
#  |      Parameters
#  |      ----------
#  |      No parameters
#  |
#  |      Description:
#  |      -----------
#  |      Performs a GET HTTP request to the endpoint of the API, and stores the image in the img attribute
#  |
#  |  resize_image(self, size=())
#  |      Parameters
#  |      ----------
#  |      size: int, tuple, list
#  |
#  |      Description:
#  |      -----------
#  |      Resize the existing image with the size specified in 'size', and then replaces it.
#  |
#  |  restore_image(self)
#  |      Parameters
#  |      ----------
#  |      No parameters
#  |
#  |      Description:
#  |      -----------
#  |      Replaces the existing image with the original one.
#  |
#  |  save_image(self, *, name='', path='')
#  |      Parameters
#  |      ----------
#  |      path: str
#  |      name: str
#  |
#  |      Description:
#  |      -----------
#  |      Saves the image requested  in the path indicated in path, with name indicated in name.
#  |      If no name is indicated, the class will use the name indicated in the response of the API.
#  |      If no path is indicated the class will save the image in /tmp
#  |
#  |  ----------------------------------------------------------------------
#  |  Data descriptors defined here:
#  |
#  |  __dict__
#  |      dictionary for instance variables (if defined)
#  |
#  |  __weakref__
#  |      list of weak references to the object (if defined)

# %%
help(fox.req_image)
# Out:
# Help on method req_image in module randomfoxapi:
#
# req_image() method of randomfoxapi.randomfoxAPI instance
#     Parameters
#     ----------
#     No parameters
#
#     Description:
#     -----------
#     Performs a GET HTTP request to the endpoint of the API, and stores the image in the img attribute

# %%
fox.req_image()

# %%
fox.img
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=960x639>

# %%
fox.imgsize
# Out:
# (960, 639)

# %%
help(fox.resize_image)
# Out:
# Help on method resize_image in module randomfoxapi:
#
# resize_image(size=()) method of randomfoxapi.randomfoxAPI instance
#     Parameters
#     ----------
#     size: int, tuple, list
#
#     Description:
#     -----------
#     Resize the existing image with the size specified in 'size', and then replaces it.

# %%
fox.resize_image(200)
fox.img
# Out:
# <PIL.Image.Image image mode=RGB size=200x200>

# %%
fox.resize_image((150, 150))
fox.img
# Out:
# <PIL.Image.Image image mode=RGB size=150x150>

# %%
fox.resize_image([300,300])
fox.img
# Out:
# <PIL.Image.Image image mode=RGB size=300x300>

# %%
fox.resize_image('100')
# Out:
# 100 is string, and must be a positive integer

# %%
fox.resize_image(['100','100'])
# Out:
# 100 is <class 'str'>, 100 is <class 'str'>, and both must be positive integers

# %%
fox.resize_image(['a','b'])
# Out:
# a is <class 'str'>, b is <class 'str'>, and both must be positive integers

# %%
fox.resize_image(['100',100])
# Out:
# 100 is <class 'str'>, 100 is <class 'int'>, and both must be positive integers

# %%
help(fox.restore_image)
# Out:
# Help on method restore_image in module randomfoxapi:
#
# restore_image() method of randomfoxapi.randomfoxAPI instance
#     Parameters
#     ----------
#     No parameters
#
#     Description:
#     -----------
#     Replaces the existing image with the original one.

# %%
fox.restore_image()
fox.img
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=960x639>

# %%
help(fox.save_image)
# Out:
# Help on method save_image in module randomfoxapi:
#
# save_image(*, name='', path='') method of randomfoxapi.randomfoxAPI instance
#     Parameters
#     ----------
#     path: str
#     name: str
#
#     Description:
#     -----------
#     Saves the image requested  in the path indicated in path, with name indicated in name.
#     If no name is indicated, the class will use the name indicated in the response of the API.
#     If no path is indicated the class will save the image in /tmp

# %%
fox.save_image()
# Out:
# 49.jpg saved at /tmp

# %%
fox.save_image(name='fox_in_tmp')
# Out:
# fox_in_tmp.jpg saved at /tmp

# %%
fox.save_image(name='fox_in_path',path='~/github/sobre-apis/')
# Out:
# fox_in_path.jpg saved at /home/stefanos/github/sobre-apis/

# %%
fox.save_image(name='fox_in_cwd',path='.')
# Out:
# fox_in_cwd.jpg saved at .

# %%
fox.save_image(name='fox_in_parent_dir',path='..')
# Out:
# fox_in_parent_dir.jpg saved at ..

# %%
fox.save_image(name='fox_can_not_be_saved',path='plop')
# Out:
# plop does not exist
