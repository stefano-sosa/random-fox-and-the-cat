# %% [markdown]
# # Random Fox API

# %%
from randomfoxapi import randomfoxAPI

# %%
fox = randomfoxAPI()

# %%
fox.req_image()

# %%
fox.img
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=480x600>

# %%
fox.imgsize
# Out:
# (480, 600)

# %%
fox.resize_image(500)
fox.img
# Out:
# <PIL.Image.Image image mode=RGB size=500x500>

# %%
fox.resize_image((500, 500))
fox.img
# Out:
# <PIL.Image.Image image mode=RGB size=500x500>

# %%
fox.resize_image([500,500])
fox.img
# Out:
# <PIL.Image.Image image mode=RGB size=500x500>

# %%
fox.save_image(name='resized_fox_in_tmp')

# %%
fox.save_image(name='resized_fox_in_path',path='~/github/sobre-apis/')

# %%
fox.save_image(name='resized_fox_in_cwd',path='.')

# %%
fox.save_image(name='resized_fox_in_parent_dir',path='..')

# %%
fox.save_image(name='resized_fox_can_not_be_saved',path='plop')
# Out:
# plop does not exist
