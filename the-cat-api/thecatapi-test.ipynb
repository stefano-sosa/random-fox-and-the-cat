# %% [markdown]
# # The cat API

# %% [markdown]
# * [Docs](https://documenter.getpostman.com/view/5578104/RWgqUxxh)
# * [Documentation Portal](https://developers.thecatapi.com/view-account/ylX4blBYT9FaoVd6OhvR?report=bOoHBz-8t)

# %%
from thecat import catAPI

# %%
cat = catAPI()

# %%
cat.req_version()

# %%
cat.version
# Out:
# 'The Cat API 1.3.9'

# %%
cat.req_breeds()

# %%
cat.breeds
# Out:
#                   Name    id
# 0           Abyssinian  abys
# 1               Aegean  aege
# 2     American Bobtail  abob
# 3        American Curl  acur
# 4   American Shorthair  asho
# ..                 ...   ...
# 62           Tonkinese  tonk
# 63              Toyger  toyg
# 64      Turkish Angora  tang
# 65         Turkish Van  tvan
# 66      York Chocolate  ycho
#
# [67 rows x 2 columns]

# %%
cat.req_images()

# %%
cat[0]
# Out:
# <PIL.Image.Image image mode=RGB size=256x256>

# %%
cat.req_images()

# %%
cat[0]
# Out:
# <PIL.Image.Image image mode=RGB size=256x256>

# %%
cat.req_images(limit=2, breed='Abyssinian')

# %%
cat[0]
# Out:
# <PIL.Image.Image image mode=RGB size=256x256>

# %%
cat[1]
# Out:
# <PIL.Image.Image image mode=RGB size=256x256>

# %%
cat[2]
# Out:
# There are only 2 elements

# %%
cat.req_images(limit=4, breed='American Bobtail')

# %%
cat[0]
# Out:
# <PIL.Image.Image image mode=RGB size=256x256>

# %%
cat[1]
# Out:
# <PIL.Image.Image image mode=RGB size=256x256>

# %%
cat[2]
# Out:
# <PIL.Image.Image image mode=RGB size=256x256>

# %%
cat[3]
# Out:
# <PIL.Image.Image image mode=RGB size=256x256>

# %%
cat[4]
# Out:
# There are only 4 elements

# %%
cat[5]
# Out:
# There are only 4 elements

# %%
cat[6]
# Out:
# There are only 4 elements

# %%
cat.create_collage()

# %%
cat.collage
# Out:
# <PIL.Image.Image image mode=RGBA size=512x512>

# %%
cat.req_images(limit=3, breed='York Chocolate')

# %%
cat.create_collage()

# %%
cat.collage
# Out:
# <PIL.Image.Image image mode=RGBA size=256x768>

# %%
cat.req_images(limit=3, breed='Aegean')

# %%
cat.create_collage()

# %%
cat.collage
# Out:
# <PIL.Image.Image image mode=RGBA size=256x768>
